# %%
import matplotlib.pyplot as plt

year  = ['2010', '2011' , '2012' , '2013' , '2014','2015']
apl   = [198 , 199  , 196  , 200  ,  201, 199]
tsl   = [210 , 200  , 190  , 198  ,  201, 198]

# %%
plt.plot(year, apl)

plt.plot(year,tsl)

plt.title('Tesla vs Apple Stock Comaprison')

plt.xlabel('Year')
plt.ylabel('Stock Price')

plt.show()
